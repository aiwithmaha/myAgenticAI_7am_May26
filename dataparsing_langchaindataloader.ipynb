# %% [markdown]
# - in langchain , we call then document loaders, They load files like PDF, DOCX, CVS,  TXT, HTML and JSON , may user parser lib like pypdf

# %%
from langchain_community.document_loaders import (
TextLoader,
PyPDFLoader,
CSVLoader,
Docx2txtLoader,
JSONLoader,
UnstructuredWordDocumentLoader,
UnstructuredHTMLLoader

)

# %%
myloader=PyPDFLoader("D:\MAHA\AIPro\AgenticAI\myAgenticAI_7am_May26\sample_document.pdf")

# %%
mydocs=myloader.load()

# %%
mydocs
# Out:
# [Document(metadata={'producer': 'ReportLab PDF Library - (opensource)', 'creator': '(unspecified)', 'creationdate': '2026-07-04T16:55:50+00:00', 'author': '(anonymous)', 'keywords': '', 'moddate': '2026-07-04T16:55:50+00:00', 'subject': '(unspecified)', 'title': '(anonymous)', 'trapped': '/False', 'source': 'D:\\MAHA\\AIPro\\AgenticAI\\myAgenticAI_7am_May26\\sample_document.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1'}, page_content='LangChain PDF Loader Sample\nThis PDF is used to demonstrate PyPDFLoader in LangChain.\nRefund Policy\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\nSupport SLA\nPriority 1 tickets should receive a first response within 2 hours.\nPolicy\nOwner\nUpdate Frequency\nRefund Policy\nSupport\nQuarterly\nLeave Policy\nHR\nYearly')]

# %%
mydocs[0].metadata
# Out:
# {'producer': 'ReportLab PDF Library - (opensource)',
#  'creator': '(unspecified)',
#  'creationdate': '2026-07-04T16:55:50+00:00',
#  'author': '(anonymous)',
#  'keywords': '',
#  'moddate': '2026-07-04T16:55:50+00:00',
#  'subject': '(unspecified)',
#  'title': '(anonymous)',
#  'trapped': '/False',
#  'source': 'D:\\MAHA\\AIPro\\AgenticAI\\myAgenticAI_7am_May26\\sample_document.pdf',
#  'total_pages': 1,
#  'page': 0,
#  'page_label': '1'}

# %%
print(mydocs[0].page_content)
# Out:
# LangChain PDF Loader Sample
# This PDF is used to demonstrate PyPDFLoader in LangChain.
# Refund Policy
# Refunds are allowed within 7 days of purchase if the product is unused and the invoice is available.
# Support SLA
# Priority 1 tickets should receive a first response within 2 hours.
# Policy
# Owner
# Update Frequency
# Refund Policy
# Support
# Quarterly
# Leave Policy
# HR
# Yearly

# %%
textloader=TextLoader("D:\MAHA\AIPro\AgenticAI\myAgenticAI_7am_May26\sampletext.txt")
txtdocs=textloader.load()
txtdocs
print(txtdocs[0].page_content)
# Out:
# LangChain Starter Parser Sample
#
# This text file is used to demonstrate TextLoader.
#
# RAG stands for Retrieval-Augmented Generation. In a RAG pipeline, documents are parsed, split into chunks, converted into embeddings, stored in a vector database, and retrieved at query time.
#
# Refund Policy Example:
# Refunds are allowed within 7 days of purchase if the product is unused and the invoice is available.

# %%
myCSVloader=CSVLoader("D:\MAHA\AIPro\AgenticAI\myAgenticAI_7am_May26\sample_data.csv")
myData=myCSVloader.load()

# %%
print(myData[0].page_content)
# Out:
# policy_id: P-001
# department: HR
# topic: Leave Policy
# details: Employees get 18 paid leaves per year.
# last_updated: 2026-01-10

# %%
Jsonloader=JSONLoader("D:\MAHA\AIPro\AgenticAI\myAgenticAI_7am_May26\sample_data.json", 
                      jq_schema=".[]", 
                      text_content=False)

# %%
jsonDocs=Jsonloader.load()

# %%
turedHTMLloader=UnstructuredHTMLLoader("D:\MAHA\AIPro\AgenticAI\myAgenticAI_7am_May26\sample_page.html")

# %%
turedHTMLloader.load()
# Out:
# [Document(metadata={'source': 'D:\\MAHA\\AIPro\\AgenticAI\\myAgenticAI_7am_May26\\sample_page.html'}, page_content='Company Knowledge Base\n\nRefund Policy\n\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\n\nSupport SLA\n\nPriority 1 tickets should receive a first response within 2 hours.\n\nChannel: Email\n\nChannel: Chat\n\nChannel: Phone')]

# %%
print(turedHTMLloader.load()[0].page_content)
# Out:
# Company Knowledge Base
#
# Refund Policy
#
# Refunds are allowed within 7 days of purchase if the product is unused and the invoice is available.
#
# Support SLA
#
# Priority 1 tickets should receive a first response within 2 hours.
#
# Channel: Email
#
# Channel: Chat
#
# Channel: Phone

# %%
mydocxloader=Docx2txtLoader("D:\MAHA\AIPro\AgenticAI\myAgenticAI_7am_May26\sample_document.docx")

# %%
mydocxloader.load()
# Out:
# [Document(metadata={'source': 'D:\\MAHA\\AIPro\\AgenticAI\\myAgenticAI_7am_May26\\sample_document.docx'}, page_content='LangChain DOCX Loader Sample\n\nThis document is used to demonstrate Docx2txtLoader in LangChain.\n\nRefund Policy\n\nRefunds are allowed within 7 days of purchase if the product is unused and the invoice is available.\n\nLeave Policy\n\nEmployees receive 18 paid leaves per year and 8 sick leaves per year.\n\nSimple Table\n\nPolicy\n\nOwner\n\nUpdate Frequency\n\nRefund Policy\n\nSupport\n\nQuarterly\n\nLeave Policy\n\nHR\n\nYearly')]

# %%
from langchain_community.document_loaders import UnstructuredMarkdownLoader
